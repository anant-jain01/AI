# %%
import numpy as np
import matplotlib.pyplot as mlt
import pandas as pd
import seaborn as sns

# %%
df=sns.load_dataset('tips')
df.corr(numeric_only=True)
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
sns.jointplot(x='tip',y='total_bill',data=df,kind='reg')

# %% [markdown]
# FOR UNIVARIATE JOINTPLOT FR BIVARIATE PAIRPLOT

# %%
sns.pairplot(df,diag_kind='kde',hue='smoker')

# %%
sns.distplot(df['tip'])
# Out:
# C:\Users\Anant Jain\AppData\Local\Temp\ipykernel_24832\4235560333.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['tip'])
# <Axes: xlabel='tip', ylabel='Density'>

# %%
sns.distplot(df['tip'],kde=False,bins=10)
# Out:
# C:\Users\Anant Jain\AppData\Local\Temp\ipykernel_24832\184943267.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['tip'],kde=False,bins=10)
# <Axes: xlabel='tip'>

# %% [markdown]
# FROM HERE ALL ARE FOR NON CATEGORICAL ERGO NON MATHAMATICAL TERMS ALSO

# %%
sns.countplot(x='size',data=df)
# Out:
# <Axes: xlabel='size', ylabel='count'>

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.countplot(y='day',data=df)
# Out:
# <Axes: xlabel='count', ylabel='day'>

# %% [markdown]
# BARPLOT IS SAME JUST BOTH VALUES ARE NEEDED

# %%
sns.barplot(y='tip',x='sex',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.boxplot(x='time',y='tip',data=df)
# Out:
# <Axes: xlabel='time', ylabel='tip'>

# %%
sns.boxplot(orient='v',data=df,palette='rainbow')
# Out:
# <Axes: >

# %%
sns.violinplot(x='tip',y='day',data=df,palette='rainbow')
# Out:
# C:\Users\Anant Jain\AppData\Local\Temp\ipykernel_24832\3968605294.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='tip',y='day',data=df,palette='rainbow')
# <Axes: xlabel='tip', ylabel='day'>
