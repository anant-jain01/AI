# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline 
#or use plt.show() everytime

# %%
x=np.arange(-1,9)
y=np.arange(11,21)
a=np.arange(40,50)
b=np.arange(50,60)

# %%
plt.scatter(x,y,c='b')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Graph')
# Out:
# Text(0.5, 1.0, 'Graph')

# %%
y=x*x

# %%
plt.plot(x,y,'r')

# %%
plt.plot(x,y,'ro--')

# %%
plt.subplot(2,2,1)
plt.plot(x,y,'ro')
plt.subplot(2,2,2)
plt.plot(x,y,'b')
plt.subplot(2,2,4)
plt.plot(x,y,'g')

# %%
x=np.arange(0,4*np.pi,0.1)#step size
y=np.sin(x)
plt.plot(x,y,'r*--')
plt.title('sin wave')
# Out:
# Text(0.5, 1.0, 'sin wave')

# %%
x=np.arange(5)
y=np.arange(3,8)
x2=[2,5,1]
y2=[7,5,9]
plt.bar(x,y,color='r')
plt.bar(x2,y2,color='b')
# Out:
# <BarContainer object of 3 artists>

# %%
plt.hist(x)
# Out:
# (array([1., 0., 1., 0., 0., 1., 0., 1., 0., 1.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
data=[np.random.normal(0,std,100) for std in range (1,4)]
plt.boxplot(data,vert=True,patch_artist=True)
#vert is for vert or hori, patch is color
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1ebfd77a0d0>,
#   <matplotlib.lines.Line2D at 0x1ebfd77a910>,
#   <matplotlib.lines.Line2D at 0x1ebfd78dd10>,
#   <matplotlib.lines.Line2D at 0x1ebfd78e5d0>,
#   <matplotlib.lines.Line2D at 0x1ebfd7996d0>,
#   <matplotlib.lines.Line2D at 0x1ebfd799fd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1ebfd77b1d0>,
#   <matplotlib.lines.Line2D at 0x1ebfd77bb10>,
#   <matplotlib.lines.Line2D at 0x1ebfd78ed90>,
#   <matplotlib.lines.Line2D at 0x1ebfd78f610>,
#   <matplotlib.lines.Line2D at 0x1ebfd79a950>,
#   <matplotlib.lines.Line2D at 0x1ebfd79b190>],
#  'boxes': [<matplotlib.patches.PathPatch at 0x1ebfd779810>,
#   <matplotlib.patches.PathPatch at 0x1ebfd78c2d0>,
#   <matplotlib.patches.PathPatch at 0x1ebfd758e50>],
#  'medians': [<matplotlib.lines.Line2D at 0x1ebfd78c490>,
#   <matplotlib.lines.Line2D at 0x1ebfd78fd90>,
#   <matplotlib.lines.Line2D at 0x1ebfd79ba50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1ebfd78cc90>,
#   <matplotlib.lines.Line2D at 0x1ebfd7986d0>,
#   <matplotlib.lines.Line2D at 0x1ebfd7b0450>],
#  'means': []}
